# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/sriml/practice/refs/heads/main/dataset_1.csv'

# %%
df = pd.read_csv(url)
df.head()
# Out:
#         Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0  10-Sep-12             7          5        0                 2          2
# 1        NaN             8          6        0                 2          2
# 2        NaN             9          8        3                 0          0
# 3        NaN            10          9        2                 0          1
# 4        NaN            11         11        1                 4          4
#
#    Unique Drivers
# 0               9
# 1              14
# 2              14
# 3              14
# 4              11

# %%
df.shape
# Out:
# (336, 7)

# %%
df.isnull().sum()
# Out:
# Date                321
# Time (Local)          0
# Eyeballs              0
# Zeroes                0
# Completed Trips       0
# Requests              0
# Unique Drivers        0
# dtype: int64

# %%
df['Date'].ffill(axis=0, inplace=True)
# Out:
# <ipython-input-8-746688a5f78d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Date'].ffill(axis=0, inplace=True)

# %%
df.head(25)
# Out:
#          Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0   10-Sep-12             7          5        0                 2          2
# 1   10-Sep-12             8          6        0                 2          2
# 2   10-Sep-12             9          8        3                 0          0
# 3   10-Sep-12            10          9        2                 0          1
# 4   10-Sep-12            11         11        1                 4          4
# 5   10-Sep-12            12         12        0                 2          2
# 6   10-Sep-12            13          9        1                 0          0
# 7   10-Sep-12            14         12        1                 0          0
# 8   10-Sep-12            15         11        2                 1          2
# 9   10-Sep-12            16         11        2                 3          4
# 10  10-Sep-12            17         12        2                 3          4
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Time (Local)        0
# Eyeballs            0
# Zeroes              0
# Completed Trips     0
# Requests            0
# Unique Drivers      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              336 non-null    object
#  1   Time (Local)      336 non-null    int64
#  2   Eyeballs          336 non-null    int64
#  3   Zeroes            336 non-null    int64
#  4   Completed Trips   336 non-null    int64
#  5   Requests          336 non-null    int64
#  6   Unique Drivers    336 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 18.5+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Time (Local)', 'Eyeballs ', 'Zeroes ', 'Completed Trips ',
#        'Requests ', 'Unique Drivers'],
#       dtype='object')

# %% [markdown]
# 1. Which date had the most completed trips during the two week period?

# %%
df.groupby('Date').agg(total_completed=('Completed Trips ', 'sum')).reset_index().sort_values('total_completed', ascending=False).head(1)
# Out:
#          Date  total_completed
# 12  22-Sep-12              248

# %% [markdown]
# 2. What was the highest number of completed trips within a 24 hour period?

# %%
df['datetime'] = df['Date']+' '+df['Time (Local)'].astype(str)+':00:00'
df.head(5)
# Out:
#         Date  Time (Local)  Eyeballs   Zeroes   Completed Trips   Requests   \
# 0  10-Sep-12             7          5        0                 2          2
# 1  10-Sep-12             8          6        0                 2          2
# 2  10-Sep-12             9          8        3                 0          0
# 3  10-Sep-12            10          9        2                 0          1
# 4  10-Sep-12            11         11        1                 4          4
#
#    Unique Drivers            datetime
# 0               9   10-Sep-12 7:00:00
# 1              14   10-Sep-12 8:00:00
# 2              14   10-Sep-12 9:00:00
# 3              14  10-Sep-12 10:00:00
# 4              11  10-Sep-12 11:00:00

# %%
df.set_index('datetime', inplace=True)

# %%
df.head()
# Out:
#                          Date  Time (Local)  Eyeballs   Zeroes   \
# datetime
# 10-Sep-12 7:00:00   10-Sep-12             7          5        0
# 10-Sep-12 8:00:00   10-Sep-12             8          6        0
# 10-Sep-12 9:00:00   10-Sep-12             9          8        3
# 10-Sep-12 10:00:00  10-Sep-12            10          9        2
# 10-Sep-12 11:00:00  10-Sep-12            11         11        1
#
#                     Completed Trips   Requests   Unique Drivers
# datetime
# 10-Sep-12 7:00:00                  2          2               9
# 10-Sep-12 8:00:00                  2          2              14
# 10-Sep-12 9:00:00                  0          0              14
# 10-Sep-12 10:00:00                 0          1              14
# 10-Sep-12 11:00:00                 4          4              11

# %%
df_rolling = df['Completed Trips '].rolling(24,min_periods=1).sum().shift(-23)

# %%
df_rolling.sort_values(ascending=False).head(1)
# Out:
# datetime
# 21-Sep-12 17:00:00    278.0
# Name: Completed Trips , dtype: float64

# %%
df_rolling.
